# %%
from main import main

# %%
# %tb
# Out:
# No traceback available to show.

# %%
main(args={
    'imported_cases_per_step_range': [0.0],
    'powers': [1.0],
    'extra_scale': [10.0/7],
    'num_population': [1000],
})
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loaded policy
# Params(imported_cases_per_step=0.0, power=1.0, extra_scale=1.4285714285714286, num_population=1000)
# policy
# value function
# initial num infected: (90, 100)
# > /home/ubuntu/pandemic_RL/code/test.py(29)test_environment()
# -> for t in range(100):
# (Pdb)  c
#   0%|          | 0/1 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-43a8e18d325b> in <module>
# ----> 1 main(args={
#       2     'imported_cases_per_step_range': [0.0],
#       3     'powers': [1.0],
#       4     'extra_scale': [10.0/7],
#       5     'num_population': [1000],
#
# ~/pandemic_RL/code/main.py in main(args)
#      90
#      91         print(particular_parameters)
# ---> 92         test_environment(env, policy, V)
#      93
#      94     # experiment.checkpoint(path="lookup_tables")
#
# ...

# %%
# %debug

# %%
env.P
