# %%
from main import main

# %%
# %tb
# Out:
# No traceback available to show.

# %%
main(args={
    'imported_cases_per_step_range': [0.0],
    'powers': [1.0],
    'extra_scale': [10.0/7],
    'num_population': [1000],
})
# Out:
# ...
#   0%|          | 0/10202 [00:00<?, ?it/s]
# Computing transition probabilities
# ...
#   8%|▊         | 822/10202 [01:18<16:19,  9.58it/s]

# %%
# %debug

# %%
env.P
