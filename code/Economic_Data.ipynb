# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
gdp = pd.read_csv('../data/Q2-GDP-international.csv')
gdp
# Out:
#       LOCATION INDICATOR SUBJECT   MEASURE FREQUENCY     TIME      Value  \
# 0          KOR      QGDP     TOT  PC_CHGPP         Q  2018-Q3   0.577085
# 1          KOR      QGDP     TOT  PC_CHGPP         Q  2018-Q4   0.865440
# 2          KOR      QGDP     TOT  PC_CHGPP         Q  2019-Q1  -0.339694
# 3          KOR      QGDP     TOT  PC_CHGPP         Q  2019-Q2   1.014143
# 4          KOR      QGDP     TOT  PC_CHGPP         Q  2019-Q3   0.375455
# ..         ...       ...     ...       ...       ...      ...        ...
# 397  EU27_2020      QGDP     TOT  PC_CHGPP         Q  2019-Q2   0.251331
# 398  EU27_2020      QGDP     TOT  PC_CHGPP         Q  2019-Q3   0.324597
# 399  EU27_2020      QGDP     TOT  PC_CHGPP         Q  2019-Q4   0.085697
# 400  EU27_2020      QGDP     TOT  PC_CHGPP         Q  2020-Q1  -3.175750
# 401  EU27_2020      QGDP     TOT  PC_CHGPP         Q  2020-Q2 -11.699983
#
#     Flag Codes
# 0          NaN
# 1          NaN
# 2            P
# 3            P
# ...

# %%
country_codes = pd.read_csv('/data/JHU-case-counts/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv')
country_codes.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region       Lat  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN    Afghanistan  33.93911
# 1    8   AL  ALB    8.0   NaN    NaN            NaN        Albania  41.15330
# 2   12   DZ  DZA   12.0   NaN    NaN            NaN        Algeria  28.03390
# 3   20   AD  AND   20.0   NaN    NaN            NaN        Andorra  42.50630
# 4   24   AO  AGO   24.0   NaN    NaN            NaN         Angola -11.20270
#
#        Long_ Combined_Key  Population
# 0  67.709953  Afghanistan  38928341.0
# 1  20.168300      Albania   2877800.0
# 2   1.659600      Algeria  43851043.0
# 3   1.521800      Andorra     77265.0
# 4  17.873900       Angola  32866268.0

# %%
case_counts = pd.read_csv('/data/JHU-case-counts/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
case_counts
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 261            NaN  West Bank and Gaza  31.952200  35.233200        0
# 262            NaN      Western Sahara  24.215500 -12.885800        0
# 263            NaN               Yemen  15.552727  48.516388        0
# 264            NaN              Zambia -13.133897  27.849332        0
# 265            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  8/16/20  8/17/20  \
# ...
